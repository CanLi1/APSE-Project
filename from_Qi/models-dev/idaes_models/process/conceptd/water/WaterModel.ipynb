# %%
from main import *

# %%
main()
# Out:
# LOA initialization MIP proposes a configuration of:
# tru1
# tru2
# tru3
# tru4
# tru5
# Local NLP took 0.06s
# NLP subproblem found local solution of 406961.235848
# Solved initialization NLP. Adding OA cuts.
# LOA Iteration 1
# MIP took 0.06s
# MIP Master: 300707.0 L: 300707.0 U: 406961.0 Base: 300707.0
# MIP proposes a configuration of:
# tru1
# tru5
# Local NLP took 0.03s
# NLP subproblem found local solution of 349524.678575
#
# LOA Iteration 2
# MIP took 0.07s
# MIP Master: 301255.0 L: 301255.0 U: 349525.0 Base: 301255.0
# MIP proposes a configuration of:
# tru2
# tru5
# Local NLP took 0.03s
# NLP subproblem found local solution of 416301.896746
# LOA terminates on NLP non-improvement.
# LOA algorithm did not converge within iteration limit. LB: 301255.0 UB: 349525.0 after 1 iterations
#
# GLOA Iteration 1
# Performing bound contraction
# Ran bound contraction on 25 variables
# Improved 0 LB, 5 block LB, 25 UB, and 5 block UB
# MIP took 0.05s
# ...
